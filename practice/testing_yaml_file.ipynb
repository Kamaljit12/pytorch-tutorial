# %% [markdown]
# ### Working with yaml file

# %%
import yaml


with open("../config.yaml", "r") as f:
    config = yaml.safe_load(f)

print(config)
# Out:
# {'database': {'host': 'localhost', 'port': 5432, 'name': 'my_app_db'}, 'users': [{'name': 'alice', 'role': 'admin'}, {'name': 'bob', 'role': 'user'}]}
